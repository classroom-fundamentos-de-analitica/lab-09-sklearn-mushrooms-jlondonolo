# %% [markdown]
# ## Importar librerías

# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %%
df_train = pd.read_csv('train_dataset.csv')
df_test = pd.read_csv('test_dataset.csv')
df_train.head()
# Out:
#   type cap_shape cap_surface cap_color bruises odor gill_attachment  \
# 0    p         x           y         n       t    p               f
# 1    e         f           y         g       t    n               f
# 2    e         x           y         y       t    a               f
# 3    e         x           s         w       f    n               f
# 4    e         x           f         n       t    n               f
#
#   gill_spacing gill_size gill_color  ... stalk_surface_below_ring  \
# 0            c         n          p  ...                        s
# 1            c         b          p  ...                        s
# 2            c         b          k  ...                        s
# 3            w         b          k  ...                        s
# 4            c         b          p  ...                        s
#
#   stalk_color_above_ring stalk_color_below_ring veil_type veil_color  \
# 0                      w                      w         p          w
# 1                      g                      g         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      p                      w         p          w
#
#   ring_number ring_type spore_print_color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 k          y       d
# 2           o         p                 n          n       m
# 3           o         e                 k          a       g
# 4           o         p                 n          v       d
#
# [5 rows x 23 columns]

# %%
df_train.columns
# Out:
# Index(['type', 'cap_shape', 'cap_surface', 'cap_color', 'bruises', 'odor',
#        'gill_attachment', 'gill_spacing', 'gill_size', 'gill_color',
#        'stalk_shape', 'stalk_root', 'stalk_surface_above_ring',
#        'stalk_surface_below_ring', 'stalk_color_above_ring',
#        'stalk_color_below_ring', 'veil_type', 'veil_color', 'ring_number',
#        'ring_type', 'spore_print_color', 'population', 'habitat'],
#       dtype='object')

# %%
df_train.replace('?', np.nan, inplace=True)
df_test.replace('?', np.nan, inplace=True)

# %%
df_train['type'] = df_train['type'].map({'p': 1, 'e': 0})
df_test['type'] = df_test['type'].map({'p': 1, 'e': 0})

# %%
from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder object
label_encoder = LabelEncoder()

# Iterate over the columns in df_train and df_test
for col in df_train.columns:
    if col != 'type':
        # Encode the column using LabelEncoder
        df_train[col] = label_encoder.fit_transform(df_train[col])
        df_test[col] = label_encoder.transform(df_test[col])

# %%
df_encoded = df_train.copy()

# %%
df_encoded.head()
# Out:
#    type  cap_shape  cap_surface  cap_color  bruises  odor  gill_attachment  \
# 0     1          5            3          4        1     6                1
# 1     0          2            3          3        1     5                1
# 2     0          5            3          9        1     0                1
# 3     0          5            2          8        0     5                1
# 4     0          5            0          4        1     5                1
#
#    gill_spacing  gill_size  gill_color  ...  stalk_surface_below_ring  \
# 0             0          1           7  ...                         2
# 1             0          0           7  ...                         2
# 2             0          0           4  ...                         2
# 3             1          0           4  ...                         2
# 4             0          0           7  ...                         2
#
#    stalk_color_above_ring  stalk_color_below_ring  veil_type  veil_color  \
# 0                       7                       7          0           2
# 1                       3                       3          0           2
# 2                       7                       7          0           2
# 3                       7                       7          0           2
# 4                       6                       7          0           2
#
#    ring_number  ring_type  spore_print_color  population  habitat
# 0            1          4                  2           3        5
# 1            1          4                  2           5        0
# 2            1          4                  3           2        3
# 3            1          0                  2           0        1
# 4            1          4                  3           4        0
#
# [5 rows x 23 columns]

# %%
def cramers_V(var1, var2):
  crosstab = np.array(pd.crosstab(var1, var2, rownames=None, colnames=None))
  stat = chi2_contingency(crosstab)[0]
  obs = np.sum(crosstab)
  mini = min(crosstab.shape) - 1
  return (stat/(obs*mini))

rows= []

for var1 in df_encoded:
  col = []
  for var2 in df_encoded :
    cramers =cramers_V(df_encoded[var1], df_encoded[var2])
    col.append(round(cramers,2))
  rows.append(col)

cramers_results = np.array(rows)
df = pd.DataFrame(cramers_results, columns = df_encoded.columns, index =df_encoded.columns)


df
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9364\3446239502.py:6: RuntimeWarning: invalid value encountered in divide
#   return (stat/(obs*mini))
#                           type  cap_shape  cap_surface  cap_color  bruises  \
# type                      1.00       0.06         0.04       0.05     0.26
# cap_shape                 0.06       1.00         0.05       0.03     0.07
# cap_surface               0.04       0.05         1.00       0.05     0.02
# cap_color                 0.05       0.03         0.05       1.00     0.05
# bruises                   0.26       0.07         0.02       0.05     1.00
# odor                      0.95       0.06         0.06       0.11     0.44
# gill_attachment           0.02       0.02         0.04       0.06     0.02
# gill_spacing              0.12       0.01         0.11       0.17     0.09
# gill_size                 0.29       0.13         0.08       0.22     0.14
# gill_color                0.47       0.06         0.07       0.08     0.43
# stalk_shape               0.01       0.09         0.01       0.37     0.01
# stalk_root                0.17       0.13         0.10       0.15     0.33
# stalk_surface_above_ring  0.35       0.03         0.02       0.07     0.33
# stalk_surface_below_ring  0.34       0.01         0.03       0.10     0.32
# stalk_color_above_ring    0.28       0.06         0.06       0.08     0.24
# stalk_color_below_ring    0.27       0.04         0.07       0.08     0.25
# veil_type                  NaN        NaN          NaN        NaN      NaN
# veil_color                0.02       0.07         0.02       0.02     0.02
# ring_number               0.04       0.04         0.01       0.12     0.00
# ring_type                 0.37       0.04         0.05       0.30     0.60
# spore_print_color         0.58       0.07         0.06       0.09     0.39
# population                0.24       0.06         0.07       0.10     0.09
# habitat                   0.20       0.07         0.06       0.11     0.29
#
#                           odor  gill_attachment  gill_spacing  gill_size  \
# type                      0.95             0.02          0.12       0.29
# cap_shape                 0.06             0.02          0.01       0.13
# cap_surface               0.06             0.04          0.11       0.08
# cap_color                 0.11             0.06          0.17       0.22
# bruises                   0.44             0.02          0.09       0.14
# odor                      1.00             0.07          0.19       0.58
# gill_attachment           0.07             0.99          0.00       0.01
# gill_spacing              0.19             0.00          1.00       0.01
# gill_size                 0.58             0.01          0.01       1.00
# gill_color                0.15             0.63          0.11       0.62
# stalk_shape               0.33             0.03          0.01       0.05
# stalk_root                0.38             0.05          0.34       0.40
# stalk_surface_above_ring  0.18             0.01          0.20       0.03
# stalk_surface_below_ring  0.26             0.02          0.17       0.02
# stalk_color_above_ring    0.20             0.96          0.16       0.13
# stalk_color_below_ring    0.20             0.96          0.14       0.12
# veil_type                  NaN              NaN           NaN        NaN
# veil_color                0.01             0.91          0.01       0.01
# ring_number               0.55             0.05          0.06       0.04
# ring_type                 0.49             0.07          0.09       0.33
# spore_print_color         0.16             0.69          0.10       0.45
# population                0.14             0.17          0.45       0.27
# habitat                   0.14             0.19          0.30       0.25
#
#                           gill_color  ...  stalk_surface_below_ring  \
# type                            0.47  ...                      0.34
# cap_shape                       0.06  ...                      0.01
# cap_surface                     0.07  ...                      0.03
# cap_color                       0.08  ...                      0.10
# bruises                         0.43  ...                      0.32
# odor                            0.15  ...                      0.26
# gill_attachment                 0.63  ...                      0.02
# gill_spacing                    0.11  ...                      0.17
# gill_size                       0.62  ...                      0.02
# gill_color                      1.00  ...                      0.14
# stalk_shape                     0.38  ...                      0.13
# stalk_root                      0.27  ...                      0.32
# stalk_surface_above_ring        0.12  ...                      0.23
# stalk_surface_below_ring        0.14  ...                      1.00
# stalk_color_above_ring          0.18  ...                      0.20
# stalk_color_below_ring          0.18  ...                      0.21
# veil_type                        NaN  ...                       NaN
# veil_color                      0.21  ...                      0.01
# ring_number                     0.20  ...                      0.07
# ring_type                       0.27  ...                      0.27
# spore_print_color               0.24  ...                      0.18
# population                      0.18  ...                      0.10
# habitat                         0.21  ...                      0.10
#
#                           stalk_color_above_ring  stalk_color_below_ring  \
# type                                        0.28                    0.27
# cap_shape                                   0.06                    0.04
# cap_surface                                 0.06                    0.07
# cap_color                                   0.08                    0.08
# bruises                                     0.24                    0.25
# odor                                        0.20                    0.20
# gill_attachment                             0.96                    0.96
# gill_spacing                                0.16                    0.14
# gill_size                                   0.13                    0.12
# gill_color                                  0.18                    0.18
# stalk_shape                                 0.29                    0.30
# stalk_root                                  0.14                    0.14
# stalk_surface_above_ring                    0.26                    0.20
# stalk_surface_below_ring                    0.20                    0.21
# stalk_color_above_ring                      1.00                    0.42
# stalk_color_below_ring                      0.42                    1.00
# veil_type                                    NaN                     NaN
# veil_color                                  0.67                    0.48
# ring_number                                 0.60                    0.60
# ring_type                                   0.45                    0.44
# spore_print_color                           0.18                    0.17
# population                                  0.18                    0.17
# habitat                                     0.18                    0.18
#
#                           veil_type  veil_color  ring_number  ring_type  \
# type                            NaN        0.02         0.04       0.37
# cap_shape                       NaN        0.07         0.04       0.04
# cap_surface                     NaN        0.02         0.01       0.05
# cap_color                       NaN        0.02         0.12       0.30
# bruises                         NaN        0.02         0.00       0.60
# odor                            NaN        0.01         0.55       0.49
# gill_attachment                 NaN        0.91         0.05       0.07
# gill_spacing                    NaN        0.01         0.06       0.09
# gill_size                       NaN        0.01         0.04       0.33
# gill_color                      NaN        0.21         0.20       0.27
# stalk_shape                     NaN        0.03         0.11       0.39
# stalk_root                      NaN        0.02         0.07       0.20
# stalk_surface_above_ring        NaN        0.11         0.02       0.21
# stalk_surface_below_ring        NaN        0.01         0.07       0.27
# stalk_color_above_ring          NaN        0.67         0.60       0.45
# stalk_color_below_ring          NaN        0.48         0.60       0.44
# veil_type                       NaN         NaN          NaN        NaN
# veil_color                      NaN        1.00         0.00       0.01
# ring_number                     NaN        0.00         1.00       0.51
# ring_type                       NaN        0.01         0.51       1.00
# spore_print_color               NaN        0.26         0.14       0.31
# population                      NaN        0.05         0.17       0.12
# habitat                         NaN        0.07         0.19       0.09
#
#                           spore_print_color  population  habitat
# type                                   0.58        0.24     0.20
# cap_shape                              0.07        0.06     0.07
# cap_surface                            0.06        0.07     0.06
# cap_color                              0.09        0.10     0.11
# bruises                                0.39        0.09     0.29
# odor                                   0.16        0.14     0.14
# gill_attachment                        0.69        0.17     0.19
# gill_spacing                           0.10        0.45     0.30
# gill_size                              0.45        0.27     0.25
# gill_color                             0.24        0.18     0.21
# stalk_shape                            0.22        0.21     0.18
# stalk_root                             0.27        0.29     0.29
# stalk_surface_above_ring               0.18        0.10     0.09
# stalk_surface_below_ring               0.18        0.10     0.10
# stalk_color_above_ring                 0.18        0.18     0.18
# stalk_color_below_ring                 0.17        0.17     0.18
# veil_type                               NaN         NaN      NaN
# veil_color                             0.26        0.05     0.07
# ring_number                            0.14        0.17     0.19
# ring_type                              0.31        0.12     0.09
# spore_print_color                      1.00        0.09     0.11
# population                             0.09        1.00     0.26
# habitat                                0.11        0.26     1.00
#
# [23 rows x 23 columns]

# %%
with sns.axes_style("white"):
  plt.figure(figsize=(10, 8))  # Agrega el tamaño de la figura más grande
  ax = sns.heatmap(df,
           vmin=0.,
           vmax=1,
           cmap='viridis',
           annot=True,
           linewidths=0.1,
           square=True)

plt.show()

# %%
features_train = df_encoded[['odor', 'gill_color', 'spore_print_color', 'ring_type', 'stalk_surface_above_ring', 'stalk_surface_below_ring']]
features_test = df_test[['odor', 'gill_color', 'spore_print_color', 'ring_type', 'stalk_surface_above_ring', 'stalk_surface_below_ring']]

X_train = features_train
y_train = df_encoded['type']

X_test = features_test
y_test = df_test['type']

# %%
# Create a DecisionTreeClassifier object
model = DecisionTreeClassifier()

# Fit the model to the training data
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print(accuracy)

from sklearn.metrics import confusion_matrix

conf_matrix = confusion_matrix(y_test, y_pred)
print(conf_matrix)
# Out:
# 0.999015263417036
# [[1041    0]
#  [   2  988]]

# %%
import pickle

# Guardar el modelo en un archivo .pkl
with open('modelo.pkl', 'wb') as file:
    pickle.dump(model, file)
